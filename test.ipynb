# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from utils import *
from fast_metropolis import *
import seaborn as sns


# %load_ext autoreload
# %autoreload 2
# Out:
# community sizes: 482 - 518
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
metropolis = load_pickle("./results/metropolis.pickle")
houdayer_500 = load_pickle("./results/houdayer_500.pickle")
houdayer_200 = load_pickle("./results/houdayer_200.pickle")
houdayer_100 = load_pickle("./results/houdayer_100.pickle")
houdayer_50 = load_pickle("./results/houdayer_50.pickle")
results = [metropolis, houdayer_50, houdayer_100, houdayer_200, houdayer_500]

# %%
fig, ax = plt.subplots(figsize=(20,10))
colors = ['orange', 'red', 'green', 'purple']
for i, result in enumerate(results[1:]):
    ax.plot(result[0], '-', color=colors[i])
    ax.fill_between(np.arange(200000), result[1], result[2], alpha=0.2, color=colors[i])

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.set(title="Average overlap of evolution with 1000 nodes, 100 simulations (95% CI)", xlabel="steps", ylabel="average overlap")
ax.plot(houdayer_200[0], '-', color='red', label='Houdayer n_0=200')
ax.fill_between(np.arange(200000), houdayer_200[1], houdayer_200[2], alpha=0.2, color='red')
ax.plot(metropolis[1], '-', color='blue', label='Metropolis')
ax.fill_between(np.arange(200000), metropolis[0], metropolis[2], alpha=0.2, color='blue')
ax.legend()
